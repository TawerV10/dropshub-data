# %%
import pandas as pd
import numpy as np
import requests
import json

from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## Loading Data

# %%
file_url = "https://raw.githubusercontent.com/TawerV10/dropshub/main/data/alphadrops.json?token=GHSAT0AAAAAACL3E3A5XMFFEA2XTEIM6A2AZNZBB6Q"
response = requests.get(file_url)
if response.status_code == 200:
    data = json.loads(response.text)
    print(f'Count: {len(data)}')
else:
  print(response.status_code)
# Out:
# Count: 138

# %%
df = pd.DataFrame(data)
df.shape
# Out:
# (138, 10)

# %%
df.head()
# Out:
#      title              tags invest           network   status  \
# 0    Renzo         Restaking   3.2M          Ethereum  Mainnet
# 1   Butter               Dex   None            Mantle  Mainnet
# 2    Parcl       Derivatives  11.6M            Solana  Mainnet
# 3  Derivio  Derivatives, Dex   None            zkSync  Mainnet
# 4  Ambient         Dex, Defi   6.5M  Ethereum, Scroll  Mainnet
#
#                                          description  \
# 0  Renzo is a Liquid Restaking Token (LRT) and St...
# 1  Butter Swap is the premier decentralized liqui...
# 2  Parcl v3 is a perpetuals exchange designed for...
# 3  Derivio is an ecosystem of derivative protocol...
# 4  Ambient (formerly CrocSwap) is a decentralized...
#
#                                             strategy  \
# 0  ✅ Stake ETH to obtain ezETH and earn Eigenlaye...
# 1  ✅ Make swaps to earn points & fishing attempts...
# 2  ✅ Trade (1 point per $)\n✅ Provide liquidity (...
# 3  ✅ Trade perps\n✅ Trade binary options (predict...
# 4                       ✅ Trade\n✅ Provide Liquidity
#
#                                              website  \
# 0  https://app.renzoprotocol.com/?ref=0x4bb12cc38...
# 1                        https://butter.xyz/s/0T1WCK
# 2                     https://app.parcl.co/referrals
# 3                               https://derivio.xyz/
# 4                            https://ambient.finance
#
#                                       discord  \
# 0                                        None
# 1        https://discord.com/invite/butterxyz
# 2                   https://twitter.com/Parcl
# 3               https://discord.gg/RYfV4ahPeQ
# 4  https://discord.com/invite/ambient-finance
#
#                                                 logo
# 0  https://api.typedream.com/v0/document/public/1...
# 1  https://api.typedream.com/v0/document/public/1...
# 2  https://api.typedream.com/v0/document/public/1...
# 3  https://api.typedream.com/v0/document/public/1...
# 4  https://api.typedream.com/v0/document/public/1...

# %% [markdown]
# ## Initial Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        138 non-null    object
#  1   tags         133 non-null    object
#  2   invest       62 non-null     object
#  3   network      136 non-null    object
#  4   status       130 non-null    object
#  5   description  138 non-null    object
#  6   strategy     138 non-null    object
#  7   website      109 non-null    object
#  8   discord      134 non-null    object
#  9   logo         138 non-null    object
# dtypes: object(10)
# memory usage: 10.9+ KB

# %%
df.columns
# Out:
# Index(['title', 'tags', 'invest', 'network', 'status', 'description',
#        'strategy', 'website', 'discord', 'logo'],
#       dtype='object')

# %% [markdown]
# Adding new column as id for each project

# %%
df['id'] = range(1, len(df) + 1)
df.shape
# Out:
# (138, 11)

# %% [markdown]
# Handling only useful columns to build similarity model

# %%
columns = ['id', 'title', 'tags', 'invest', 'network', 'status', 'description', 'strategy']
df = df[columns]

# %%
df.head()
# Out:
#    id    title              tags invest           network   status  \
# 0   1    Renzo         Restaking   3.2M          Ethereum  Mainnet
# 1   2   Butter               Dex   None            Mantle  Mainnet
# 2   3    Parcl       Derivatives  11.6M            Solana  Mainnet
# 3   4  Derivio  Derivatives, Dex   None            zkSync  Mainnet
# 4   5  Ambient         Dex, Defi   6.5M  Ethereum, Scroll  Mainnet
#
#                                          description  \
# 0  Renzo is a Liquid Restaking Token (LRT) and St...
# 1  Butter Swap is the premier decentralized liqui...
# 2  Parcl v3 is a perpetuals exchange designed for...
# 3  Derivio is an ecosystem of derivative protocol...
# 4  Ambient (formerly CrocSwap) is a decentralized...
#
#                                             strategy
# 0  ✅ Stake ETH to obtain ezETH and earn Eigenlaye...
# 1  ✅ Make swaps to earn points & fishing attempts...
# 2  ✅ Trade (1 point per $)\n✅ Provide liquidity (...
# 3  ✅ Trade perps\n✅ Trade binary options (predict...
# 4                       ✅ Trade\n✅ Provide Liquidity

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Getting missed data

# %%
missed = df.isnull().sum()
missed[missed > 1]
# Out:
# tags        5
# invest     76
# network     2
# status      8
# dtype: int64

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Merging text of columns to summary

# %%
merge_columns = ['tags', 'invest', 'network', 'status', 'description', 'strategy']
df['summary'] = df[merge_columns].apply(lambda row: ' '.join(row.dropna().astype(str).str.lower()), axis=1)

# %% [markdown]
# Cleaning from unneeded symbols

# %%
import re

to_replace = [',', '✅', '☑️', '🚨', '🔸', '\n']
def clean_text(row):
  for element in to_replace:
    row = row.replace(element, '')

  row = row[:-1] if row[-1] in ['.', ',', ':', '!', '?'] else row
  row = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', row) if 'https' in row or 'http' in row else row

  return row.replace('  ', ' ').strip()

# %%
df['summary'] = df['summary'].apply(clean_text)

# %%
for i in range(df.shape[0]):
  print(i + 1, df['summary'][i])
# Out:
# 1 restaking 3.2m ethereum mainnet renzo is a liquid restaking token (lrt) and strategy manager for eigenlayer. it is the interface to the eigenlayer ecosystem securing actively validated services (avss) and offering a higher yield than eth staking. stake eth to obtain ezeth and earn eigenlayer and renzo points
# 2 dex mantle mainnet butter swap is the premier decentralized liquidity venue on mantle the ethereum layer-2 redefining scalability with its modular architecture and decentralized data availability component. make swaps to earn points & fishing attempts use the fishing attempts to earn mnt points will be converted into butter tokens
# 3 derivatives 11.6m solana mainnet parcl v3 is a perpetuals exchange designed for real estate synthetics. it supports cross margined perps trading on various real estate markets. lps add liquidity to a single lp pool per exchange where they take on trader pnl as well as earn trading fees. trade (1 point per $) provide liquidity (3 points per $) bind referral code for 5% boost - code: alphadrops invite your friends
# 4 derivatives dex zksync mainnet derivio is an ecosystem of derivative protocol suites that can satisfy both speculative and hedging needs for a plethora of digital assets with an experience that is smooth for all traders developers and institutions. trade perps trade binary options (predict) trade spot mint and stake dlpm
# 5 dex defi 6.5m ethereum scroll mainnet ambient (formerly crocswap) is a decentralized exchange (dex) protocol that allows for two-sided amms combining concentrated and ambient constant-product liquidity on any arbitrary pair of blockchain assets. trade provide liquidity
# 6 derivatives 2m arbitrum mainnet bracketx is an application that provides leveraged structured products for non-custodial defi users as a standalone application. bracketx simplifies leveraged strategies in defi into easy to understand payoff multiples that can be purchased in a few clicks. [updated on jan 2024] trade passage participate in the community activities holding og and trading nfts can be a multiplier
# 7 lending dex stablecoin money market starknet mainnet nostra is the most versatile liquidity protocol for lending and borrowing what you can do now: lend & borrow assets to earn points keep your position open for the multiplier bonuswhat you may need to do in the future: mint $uno stablecoin trade on the nostra order-book app provide liquidity
# 8 wallet bridge 19.5m ethereum bnbchain optimism arbitrum polygon base zora mainnet the fun simple & secure way to explore web3 nfts & ethereum download now on ios and android! use the features of the wallet like making some swaps and minting an ens domain name within the wallet
# 9 restaking ethereum mainnet kelp dao was founded by amitej g and dheeraj b who have previously founded stader labs a multichain liquid staking platform with $215m+ in tvl. the team is focused on building liquid restaking solutions for public blockchain networks. restake liquid staking assets (steth ethx etc) to earn points
# 10 bridge infrastructure 18.5m celestia arbitrum manta neutron mainnet hyperlane is the first universal and permissionless interoperability layer built for the modular blockchain stack. bridge assets across different chains using apps built on hyperlane such as nexus
# 11 defi dex starknet mainnet ekubo protocol features concentrated liquidity a singleton architecture and extensions. it is designed to take full advantage of the starknet architecture with the goal of providing the best swapper execution and liquidity provider returns anywhere. make swaps on ekubo and avnu provide liquidity to earn fees and points
# 12 network nft frame testnet frame is an ethereum l2 powered by arbitrum nitro stack designed to scale nft adoption across the ethereum ecosystem. frame is evm-equivalent and supports all existing ethereum tooling including metamask foundry hardhat and more.  complete testnet quests (see below)
# 13 derivatives arbitrum mainnet hyperliquid is a decentralized perpetual exchange with best-in-class speed liquidity and price. trade and earn points invite your friends
# 14 network operating polygon ethereum bnbchain arbitrum avalanche fantom kava mainnet dappos is the first web3 operating protocol designed to make dapps as user-friendly as mobile apps.thanks to dappos solution based on account abstraction and executive network dapps can easily integrate dappos solution and users can enjoy seamless and intuitive interaction with web3 dapps from any chain use the apps supported on dappostrade & provide liquidity on perptrade lend and borrow on benqitrade & provide liquidity on quickswap
# 15 liquid staking defi 3.8m ethereum arbitrum mainnet swell is liquid staking made simple with the mission is to deliver the world’s best liquid staking experience and simplify access to defi. join the voyage & earn pearls stake eth to get sweth lp sweth on pools incentivized with pearls restake sweth on eigenlayerthe pearls will be converted into swell tokens later
# 16 defi lending bnbchain confirmed mainnet kinza finance is the next-generation decentralized lending protocol on bnb chain. kinza finance is non-custodial permissionless secure and incorporates cutting-edge defi mechanisms and solutions to offer users a flexible and highly customizable defi lending experience. built-in mechanisms and rewards incentivize participation and innovative tokenomics ensure unparalleled sustainability. 1. lend and borrow assets2. follow announcements on discord
# 17 network 80m scroll mainnet a native zkevm layer 2 solution for ethereum use the testnet and claim galxe oats use mainnet (bridge trade lp lend trade nfts etc.)
# 18 privacy network 6m ten testnet ten is an evm equivalent encrypted l2 solution for ethereum. it sits between optimistic and zk rollups. ten leverages secure enclaves to encrypt the evm and hyper-scale ethereum. participate in the meet ten campaign on galxe contribute to the project by completing tasks on dework. join discord for more info. use testnet and mainnet when available
# 19 dex derivatives lending 3.8m solana mainnet drift protocol is an open-sourced decentralised exchange built on the solana blockchain enabling transparent and non-custodial trading on cryptocurrencies. trade spot & perps stake & earn yield lend & borrow
# 20 liquid staking 10m bnbchain mainnet helio protocol functions as a open-source liquidity protocol for earning yields on collateralized crypto assets (bnb/eth/stablecoins) and borrowing of our decentralized stablecoin hay also known as a "destablecoin". deposit collateral borrow $hay stablecoin stake $hay or lp on supported pools use synclub (liquid staked bnb) participate in galxe campaignsfind below a more detailed airdrop strategy
# 21 network 10m ancient8 op stack testnet ancient8 chain is a gaming-focused community-driven ethereum layer 2 powered by the op stack specifically tailored to tackle the scalability and adoption challenges faced by web3 gaming and consumer dapps. by leveraging optimistic rollups ancient8 offers unparalleled scalability lower transaction costs and near-instant confirmations. use testnet participate in the odyssey campaign (see below)
# 22 derivatives bnbchain confirmed mainnet kiloex backed by binance provides traders with lightning-fast trades real-time tracking of market activity and a intuitive trading experience while offering liquidity providers risk-neutral positions and lp-friendly solutions. 1. trade perps2. stake assets
# 23 network mode testnet mode is an ethereum layer-2 blockchain designed for hyper-growth. mode is built using optimism's op stack which enables rapid application development and deployment of evm-compatible applications. mode's network fees are 95% less than ethereum mainnet. see below
# 24 network 458m eth l2 testnet mainnet zksync is a zk rollup solving ethereum scalability with zero security compromises. bridge eth from l1 to zksync. use some dapps supporting zksync’s l2 like zigzag and gitcoin
# 25 bridge 225m multichain mainnet wormhole is a generic cross-chain messaging protocol platform. bridge across different chains on the dapps using wormhole including portal bridge carrier allbridge core mayan bridge nfts across supported chains
# 26 privacy defi 6m ethereum mainnet nocturne is a protocol enabling private accounts on ethereum. nocturne allows users to deposit or receive funds to private stealth addresses within the nocturne contracts. then in the future a user can prove ownership of assets in zero knowledge for use in arbitrary transactions or confidential transfers. deposit eth make swaps stake eth⚠️ attention: interacting with nocturne could result in high costs due to the high l1 gas fees
# 27 privacy defi 4.1m ethereum optimism bnbchain arbitrum polygon avalanche zksync base mainnet hinkal is a protocol enabling private trading & yield farming strategies on evm chains. hinkal allows liquid funds and retail users to create a private account(s) and transact on their favorite dapps entirely untraceable (the origin and destination of transaction value and private mempools) and almost free charging only 3 basis points per transaction. deposit on different chains make swaps provide liquidity stake assets participate in galxe campaigns
# 28 lending solana mainnet marginfi is a decentralized lending protocol on solana that prioritizes risk management to provide a safe and reliable solution for users looking to access leverage and maximize capital efficiency. lend borrow refer
# 29 network base mainnet a new ethereum l2 incubated by coinbase and built on the open-source op stack. use testnet and complete base quests (completed) transact on mainnet (bridge swap lp trade nfts etc)
# 30 infrastructure tools dex 20m near mainnet testnet a permissionless and modular protocol that brings high throughput low latency low fees tight spreads and composability for defi builders trade on dexs powered by orderly such as woofi dex and ref finance participate in the galxe campaigns
# 31 liquid staking restaking 5.3m ethereum mainnet ether.fi stake eth and mint fan nfts (see below)
# 32 oracle 7.9m multichain mainnet redstone is an innovative oracle system designed to provide reliable and diverse data feeds for dapps and smart contracts on multiple blockchain layers (l1s & l2s). it addresses the limitations of existing oracle protocols and offers a more efficient scalable and builders’ centred solution for the defi ecosystem. - complete quests- join the ambassador program (see below)
# 33 restaking 64.5m ethereum mainnet eigenlayer is a protocol built on ethereum that introduces restaking a new primitive in cryptoeconomic security. this primitive enables the reuse of eth on the consensus layer. restake your liquid staked eth (steth sweth cbeth etc) into the pools to earn points restake your eth with liquid restaking protocols such as renzo or etherfi testnet (see below)
# 34 network 726.7m linea mainnet a developer-ready zk rollup powered by consensys enabling the next generation of ethereum builders. join testnet voyage & claim nfts (ended) join mainnet voyage bridge to linea (native & third-party) make swaps on different apps provide liquidity create and/or trade nfts trade perps
# 35 lending money market 2.8m bnbchain arbitrum optimism ethereum avalanche polygon moonbeam mainnet prime protocol is a cross-chain prime brokerage which allows users to borrow across chains backed by their entire portfolio of cross chain assets. at prime we are pushing the boundaries of decentralized finance by breaking down the silos between blockchains and creating one of the first cross chain xapps.  deposit & borrow assets to earn prime points get prime pioneer nft and discord roles by participating the community activities use the testnet and provide feedback (ended)
# 36 omnichain defi lending tools network 173.3m omnichain mainnet an omnichain interoperability protocol that enables the realization of cross-chain applications with a low level communication primitive. it's focused on connecting to all evm chains read our mirror article about layerzero. more info is below
# 37 infrastructure privacy bridge 25m ethereum bnbchain polygon arbitrum optimism avalanche metis gnosis moonbeam testnet mainnet polyhedra network is building the next generation of infrastructure for web3 interoperability scalability and privacy through advanced zero-knowledge proof (zkp) technology. polyhedra network provides trust-minimized and highly-efficient interoperability solutions for asset transfers message passing and data sharing between various web2 and web3 systems. - use the testnet and mainnet- participate in their galxe campaign- join the community
# 38 money market dex defi 9m ethereum bnbchain base zksync mainnet the defi infrastructure built to facilitate the most liquid markets powered by maverick amm.  preseason airdrop (completed) season 1 incentives: provide liquidity governance airdrop: lock mav to get vemav
# 39 network 273m starknet testnet mainnet starknet is a permissionless decentralized zk-rollup. it operates as an l2 network over ethereum enabling any dapp to achieve unlimited scale for its computation – without compromising ethereum's composability and security. use the dapps and projects built on starknet and complete the starknet quests (if there are any).also read our mirror article
# 40 network 22m taiko confirmed testnet a decentralized ethereum-equivalent zk-rollup. complete their galxe quests and claim loyalty points. link
# 41 derivatives 10m linea zksync polygon zkevm scroll mainnet satori is a decentralized financial derivatives platform built on polygon zkevm zksync and scroll. it features an order book model in collaboration with many market makers to provide comprehensive exposure to a wide range of assets and an “off-chain aggregation and on-chain settlement” design that combines the security and transparency of a decentralized exchange with the speed and usability of a centralized exchange. trade perps on different networks participate in their galxe campaigns participate in governance
# 42 nft network ethereum mainnet nft marketplace mint/trade nfts. hold a zorb nft
# 43 80m fuel ethereum testnet fuel labs is building fuel the fastest modular execution layer. - use the testnet (guides will be updated)- join community
# 44 dex zksync starknet zklink testnet zkex is a multi-chain order book dex secured with zero-knowledge proofs powered by @zklinkorg @starkwareltd and @zksync complete quests zkex
# 45 dex 16.5m starknet testnet a decentralized trustless and cross-chain order-book exchange for traders. they offer a unique and simple user experience with an intuitive ui including profit-loss analysis while guaranteeing simple cex to dex portability. trade and complete quests to earn salt score
# 46 network infrastructure eth l2 testnet mainnet a unified multi-chain l2 network secured by revolutionary zero-knowledge technology use the testnet and participate in the weekly quizzes
# 47 derivatives arbitrum mainnet the most liquid composable and omnichain eth perp. trade deposit into the vaults join discord and guild to get the roles and participate in the community activities
# 48 stablecoin liquid staking 30m ethereum mainnet decentralized borrowing & steth-backed r stablecoin developed by tempus finance. raft wave 1 airdrop is finished. we're expecting wave 2 airdrop as well. deposit lsts & mint r (3000 r minimum) deposit r into the savings (earn 8% apr) provide liquidity to pools and stake lp (balancer maverick gyro etc) stake raft to get veraft participate in governance use the app on different chains
# 49 defi lending 2.5m arbitrum mainnet margin trade and borrow defi bluechips like never before while earning increased apr on held assets - all from your desktop or mobile wallets. trade lend and borrow complete missions to earn xp and level up
# 50 network opside testnet a three-layer architecture for high-throughput web3 applications. use the testnet
# 51 bridge 5.5m bnbchain polygon ethereum avalanche optimism linea mainnet cross-chain interoperability protocol enabling transfers of assets and data between blockchains in one transaction bridge between various networks on both deswap and dln trade apps complete quests and claim oats
# 52 dashboard social multichain mainnet multi-chain asset management dashboard use the dapp
# 53 nft 19.5m ethereum mainnet the fastest safest and most rewarding way to mint all the top new nft projects. - mint !fundrop free nft- complete the goals and collect points
# 54 wallet bridge dashboard dex 726m ethereum mainnet a crypto wallet & gateway to blockchain apps - use its in-app swap feature on eth network- use the mm bridge swap and staking features- participate in social activities and collect poaps if there are any- use the consensys testnet
# 55 defi arbitrum testnet building a dynamic hedging vault to enable uncorrelated market-neutral returns join alpha
# 56 dex bnbchain polygon ethereum arbitrum optimism mainnet a dex supporting multiple chains swap on multiple chains
# 57 network eth l2 optimism mainnet optimism is a layer 2 optimistic rollup network designed to utilize the strong security guarantees of ethereum while reducing its cost and latency. bridge eth use dapps on optimism and hold and delegate op.here are some dapps to use: #gid=1014306106
# 58 bridge 2.2m starknet zksync bnbchain polygon arbitrum optimism zkspace boba loopring immutable x arbitrum nova linea base mainnet layerswap is the ultimate l2 gateway - offering instant and gasless on and off-ramp transactions to l2s. instantly transfer eth usdc and other tokens from cex to all major l2s. transfer from cex to layer 2 networks provide feedback on discord and participate in the community activities
# 59 bridge quest 9.9m bnbchain ethereum polygon arbitrum optimism zksync gnosis aurora fantom avalanche base mainnet layer3 is a crypto platform that provides tools for decentralized autonomous organizations (daos). accomplish quests and earn xps. also join discord and be active
# 60 quest 21.6m multichain mainnet learn crypto and become a contributor in web3 accomplish quests and skills
# 61 bridge infrastructure 5.5m bnbchain polygon ethereum avalanche arbitrum fantom optimism mooniver moonbeam harmony okc fuse celo cronos gnosis zksync mainnet advanced bridge & dex aggregation - drive multichain strategies with cross-chain data messaging and get users from everywhere. use jumper bridge and participate in the community events
# 62 bridge 5.5m bnbchain polygon ethereum avalanche arbitrum fantom optimism mooniver moonbeam harmony okc fuse celo cronos gnosis aurora zksync mainnet crypto's everything exchange. powered by lifi protocol. - use the cross-chain swap and gas features- participate in the community activities
# 63 bridge ethereum optimism arbitrum polygon fantom gnosis avalanche aurora zksync base bnbchain mainnet swap tokens across chains bridge and use refuel
# 64 dex ethereum polygon mainnet bebop is the decentralized trading platform on a mission to reinvent user experience and execution in defi. join waitlist by submitting your wallet in discord
# 65 dashboard bridge wallet dex 33m ethereum bnbchain polygon arbitrum optimism avalanche zksync fantom gnosis aurora base mainnet zerion is an award-winning portfolio management app for decentralized finance (defi) offering a simple secure and convenient way to build your defi portfolio from one place. swap bridge and hold nfts (both genesis and dna)
# 66 derivatives 0m arbitrum mainnet synquote is a decentralized options trading platform that allows users to trade crypto options on the arbitrum network currently supporting $eth and $btc call and put options. trade options to earn points
# 67 nft 10m bnbchain tba bridge web2 to web3 through gameplay and nft.building the next-generation web3 wonderland on bsc. join the voyagers campaign
# 68 network 18m omni network testnet the layer 1 blockchain built to connect all rollups. - join the community- use the testnet- complete galxe quests and get guild roles
# 69 arbitrum polygon mainnet leveraged liquidity provision platform with automation for uniswap v3 trade on unibot collect galxe nfts and get discord roles
# 70 defi lending stablecoin 0.5m polygon mainnet davos is a first-rate cross-chain lending and borrowing platform that offers its users the opportunity to borrow the davos stable asset initially using their staked matic assets as collateral. deposit matic & borrow davos complete zealy galxe and questn tasks
# 71 privacy testnet a privacy-preserving decentralized kyc solution based on multi-party computation mpc & zero-knowledge proof zkp collect oats participate in activities and be active on discord
# 72 wallet 3m aptos sui mainnet martian wallet is a crypto wallet that can be used to manage digital assets and access decentralized applications on the sui and aptos blockchain. use the wallet on aptos sui and future move-based networks use the portfolio dapp: complete the quests to earn xp
# 73 defi 4.5m polygon ethereum mainnet swaap is the first market neutral automated market maker (amm). it leverages a combination of oracles and dynamic spread to provide sustainable yields for liquidity providers and cheaper prices to traders. provide liquidity use swap complete galxe quests
# 74 lending money market arbitrum mainnet sentiment is a decentralized credit protocol that facilitates under-collateralized lending via a "margin-account" primitive which allow users to borrow several times the value of their collateral. lend and borrow tokens
# 75 dex bridge wallet 23.3m optimism polygon bnbchain ethereum osmosis arbitrum canto mainnet web3 trading platform on polygon arbitrum optimism and more hold their nfts swap on multiple chains
# 76 defi arbitrum optimism ethereum mainnet advanced defi management. use both the mainnet and testnet
# 77 network zetachain testnet zetachain blockchain enables omnichain interoperability of any value or data use testnet to earn points. get 5000 zeta points upon sign up using this link
# 78 derivatives arbitrum avalanche mainnet the order-book decentralized derivatives exchange. token perpetuals index perpetuals and more! open a long/short position. participate in their galaxy campaigns
# 79 derivatives 1.1m optimism mainnet polynomial automates financial derivative strategies to create products that deliver passive yield on various assets. - deposit into the vaults- make some swaps- trade perps- collect polynomial’s oats and nfts
# 80 network nft mint mint is a layer 2 blockchain for nfts developed by nftscan labs and mintcore complete zealy tasks get whitelisted for mint pass
# 81 bridge bnbchain polygon ethereum avalanche arbitrum fantom moonbeam celo osmosis evmos terra kujira juno secret axelar cosmos base mantle kava injective linea mainnet squid lets you swap tokens between blockchains and unlocks access to apps across chains in 1 click this app is in beta. please wait for further updates
# 82 money flow polygon bnbchain avalanche optimism arbitrum moonbeam aurora fantom gnosis celo mainnet cask is a decentralized non-custodial protocol for automating the flow of money in web3. the cask base layer implements a job scheduling and queuing system that can handle many types of automated money flows. the foundation is built using chainlink keepers with flow-specific contracts operating above. deposit and flow money to another wallet participate in the community activities and complete layer3 quests
# 83 defi dex polygon optimism arbitrum mainnet mean enables users to dollar cost average (dca) any erc20 into any erc20 with their preferred period frequency. 1. use the platform on mainnet by creating dca positions2. complete their layer3 quests3. join the community
# 84 dex defi zksync perpdex brings you a safe trading experience which guards against draining your account using liquidity free funding reducing bad debt with lossless amm and drastically reduced oracle dependencies to improve security. use the app on both the testnet and mainnet and provide feedback on discord
# 85 defi 4m ethereum optimism polygon arbitrum mainnet arrakis provides a platform to enable projects to create deep liquidity for their tokens. largest lp on uniswap v3. provide liquidity and be active on discord
# 86 bridge bnbchain polygon ethereum fantom arbitrum optimism harmony gnosis avalanche aurora mooniver solana linea mainnet advanced cross-chain liquidity aggregation protocol use both testnet and mainnet participate in the community activities and donate on gitcoin during gr14
# 87 defi zksync mainnet dex on zksync l2 updated strategy: make some swaps provide liquidity participate in the galxe campaigns and get discord roles.finished: use testnet claim alpha tester role in their discord server donate on gitcoin and collect their galaxy nfts
# 88 bridge 2m bnbchain ethereum solana tron mainnet cross-chain stablecoin swap use the bridge on the mainnet complete crew3 and get the guild roles
# 89 dashboard bridge dex 17m ethereum bnbchain polygon arbitrum optimism avalanche base mainnet zapper is a one-stop-shop for deploying and managing defi positions. swap bridge and hold nfts
# 90 wallet ethereum mainnet argent is the first smart wallet for ethereum. it’s the only non-custodial mobile wallet that combines easy access to dapps and security features such as recovery without seed phrases trusted contacts and multisig. activate your wallet and make some swaps
# 91 tools ethereum polygon mainnet asset management for a defi world create set or invest in existing one
# 92 lending 5m starknet testnet zklend is an l2 money-market protocol built on starknet combining zk-rollup scalability superior transaction speed and cost-savings with ethereum’s security. use the testnet be active on discord participate in the community activities and use the mainnet once launched
# 93 defi solana mainnet permissionless composable index protocol complemented with user friendly portfolio management and dex make a swap
# 94 defi bridge multichain testnet mainnet cross-chain dex. trade your tokens swiftly in 3 steps magpie takes care of the complexity of cross-chain swapping for you! sign up for the alpha testing and wait an email from magpie with a link and password. once whitelisted use the app and provide feedback
# 95 tools multichain mainnet stream money stream tokens on both testnet and mainnet
# 96 defi 6m ethereum mainnet voltz protocol is a non-custodial automated market maker for interest rate swaps. make contributions to the community or trade on the protocol to earn badges
# 97 119m ethereum aztec mainnet aztec network is the first smart contract platform with privacy by default and secured by ethereum. use testnet and mainnet
# 98 defi 9m ethereum mainnet crypto native derivatives. built on the replicating market maker protocol. use testnet and mainnet: provide liquidity
# 99 defi derivatives starknet testnet zkx is a permissionless protocol for derivatives built on starknet starkware’s zk rollup. we are introducing complex trading strategies as simple perpetual swaps. complete crew3 quests to level up and get discord roles. see below
# 100 defi arbitrum ethereum mainnet invest in defi with protection against hacks exploits and more. deposit invest and protect your invest
# 101 bridge ethereum bnbchain polygon avalanche arbitrum fantom mainnet a one-click cross-chain swap any token any chain swap/bridge tokens
# 102 bridge optimism boba beam your erc20 assets between evm-compatible rollups with certainty speed and security. use the bridge participate in community activities and claim poaps and join discord and guild to get the roles
# 103 defi arbitrum mainnet structuring money legos for customizable yield deposit into a vault
# 104 wallet solana mainnet desktop and mobile wallet on solana network use in-app swap feature
# 105 defi lending ethereum arbitrum polygon mainnet tokenized volatility protocol. mint usdc swap and provide liquidity
# 106 tools dao 4m snapshot labs is an off-chain gasless multi-governance tool for crypto projects to poll their user bases. snapshot used by several companies in the defi space to help survey users. - join multiple daos and participate in the governance- be active on discord
# 107 defi dex launchpad starknet testnet starkdefi is a permissionless and trustless hub of comprehensive defi solutions built to leverage zk-rollup on starknet. make swaps and provide liquidity to earn points level up and unlock cores.finished- donate on gitcoin gr15 - complete the crew3 quests- get discord roles (level 5 and testnet)- use testnet
# 108 specular testnet specular is the first evm-native optimistic rollup that provides stronger security and decentralization properties than existing optimistic rollup solutions. use testnet. see below
# 109 wallet ethereum polygon arbitrum optimism mainnet the community owned and operated web3 wallet. install and use the wallet participate in the galxe campaigns and be active in discord
# 110 wallet dashboard 4.4m multichain mainnet coinstats is a cryptocurrency research and portfolio tracker app. complete quests collect sparks claim rewards
# 111 privacy 7m multichain zcloak network is a privacy-preserving computing platform. it enables a new computation paradigm where people can do computation/analysis of their data in client devices not in centralized servers. the integrity of their computation is proven by zero-knowledge proof. with zcloak network people can use their real-world data for e.g. defi identity biometric applications without disclosing their privacy. complete crew3 tasks
# 112 bridge iotex ethereum bnbchain mainnet iotube is a decentralized cross-chain bridge that enables the bidirectional exchange of crypto-assets (e.g. fungible/non-fungible tokens stablecoins) between iotex and other blockchain networks. bridge from/to iotex
# 113 nft lending 29m arbitrum moonbeam kusama polkadot a cross-margin universal lending protocol and buy now pay later for nft erc20 uniswap v3 and beyond. complete guides
# 114 defi dex arbitrum perps trading on almost any asset you can think of. join the community for now. more details tba and announced on our discord/twitter
# 115 dex wallet aptos mainnet pontem network creates cutting-edge products based on move that can be deployed across blockchains. liquidswap is just the beginning: our vision is a full dapp ecosystem leveraging the security and speed of aptos and move. use the testnet and mainnt
# 116 dex bridge solana ethereum bnbchain avalanche mainnet cross-chain swap auction protocol — powered by read the thread below
# 117 did 13m nervos mainnet web3.0 identities for you and your community. (previously das) - mint domain names and participate in their activities to get oats. - convert one of your domains to an ethereum nft
# 118 defi starknet testnet an amm on top of starknet (ethereum l2) testnet: mint $tst tokens swap add liquidityjoin discord
# 119 lending polygon mainnet like uniswap but for lending & borrowing lend/borrow and claim nfts on project galaxy. don’t forget to withdraw your assets. for borrowers before maturity and for lenders after maturity
# 120 bridge starknet zksync ethereum polygon optimism loopring boba immutable x metis linea base zksync lite polygon zkevm arbitrum nova mantle opbnb zora mainnet a decentralized cross-rollup bridge bridge between l2 networks get discord roles
# 121 did 72m polygon ethereum mainnet unstoppable domains provides .crypto and other top-level domain names to users with no renewal fees. when a user claims a domain it is minted as an nft on the ethereum blockchain granting the user full ownership and control. 1. mint a domain (get $10 with this link): 2. join discord and claim your role:
# 122 launchpad zksync testnet a platform for decentralized fundraising investments and payments built on zksync 2.0 claim test tokens and use the testnet
# 123 defi ethereum mainnet decentralized market making strategies add liquidity
# 124 shardeum testnet world's first evm-based l1 which uses sharding to increase tps with the addition of every new node. use testnets and be active on discord
# 125 defi dex arbitrum mainnet defi hub for users & builders. breakthrough accounting architecture and amm engine. trade provide lp vote on snapshot hold nfts and collect shell points
# 126 tools ethereum mainnet the essential web3 toolkit for sharing & funding anything: write your latest idea launch the next big dao or build your web3 home. write and mint articles and maybe donate
# 127 tools multichain mainnet stream money on the internet! steam tokens
# 128 defi starknet testnet jediswap is a fully permissionless and composable amm on starknet testnet: mint swap zap and add liquidity using argent x wallet
# 129 defi polygon mainnet bet on nfts culture politics airdrops defi covid ai the metaverse & more. make a few bets or create yours
# 130 bridge everscale ethereum solana mainnet octus bridge is an everscale powered gateway to a world of interchain transactions bridge and stake
# 131 lending polygon mainnet atlendis protocol - a capital-efficient defi protocol that enables uncollateralized crypto loans. deposit into a lending pool
# 132 gamefi zksync ethereum testnet mainnet building a gamified & decentralized metaverse on zksync network. play the game and collect karma points
# 133 nft starknet testnet the nft building protocol. use testnet
# 134 defi dex polygon ethereum arbitrum optimism odos leverages a unique algorithm to traverse a large universe of possible token swap combinations and non-linear paths delivering greater savings to its users 1. participate in the galxe campaigns and mint nfts2. join the community
# 135 defi derivatives ethereum mainnet opyn is a capital efficient defi options protocol that allows users to buy sell and create options on erc20s. deposit and open a long position
# 136 dashboard tools dex bnbchain polygon ethereum avalanche fantom arbitrum optimism moonbeam aurora okc fuse mooniver gnosis celo boba heco mainnet defi llama is a decentralized analytics dashboard that tracks defi tvl (total value locked) for projects like ethereum terra and binance. use their swap aggregator
# 137 defi ethereum testnet decentralized liquidity protocol for cross-dex margin trading. get the early user role and use testnet primex finance
# 138 defi network cosmos side testnet interchain swap (ibc swap) built by cosmonauts tba. join discord for now

# %%
df.head()
# Out:
#    id    title              tags invest           network   status  \
# 0   1    Renzo         Restaking   3.2M          Ethereum  Mainnet
# 1   2   Butter               Dex   None            Mantle  Mainnet
# 2   3    Parcl       Derivatives  11.6M            Solana  Mainnet
# 3   4  Derivio  Derivatives, Dex   None            zkSync  Mainnet
# 4   5  Ambient         Dex, Defi   6.5M  Ethereum, Scroll  Mainnet
#
#                                          description  \
# 0  Renzo is a Liquid Restaking Token (LRT) and St...
# 1  Butter Swap is the premier decentralized liqui...
# 2  Parcl v3 is a perpetuals exchange designed for...
# 3  Derivio is an ecosystem of derivative protocol...
# 4  Ambient (formerly CrocSwap) is a decentralized...
#
#                                             strategy  \
# 0  ✅ Stake ETH to obtain ezETH and earn Eigenlaye...
# 1  ✅ Make swaps to earn points & fishing attempts...
# 2  ✅ Trade (1 point per $)\n✅ Provide liquidity (...
# 3  ✅ Trade perps\n✅ Trade binary options (predict...
# 4                       ✅ Trade\n✅ Provide Liquidity
#
#                                              summary
# 0  restaking 3.2m ethereum mainnet renzo is a liq...
# 1  dex mantle mainnet butter swap is the premier ...
# 2  derivatives 11.6m solana mainnet parcl v3 is a...
# 3  derivatives dex zksync mainnet derivio is an e...
# 4  dex defi 6.5m ethereum scroll mainnet ambient ...

# %%
new_df = df[['id', 'title', 'summary']]

# %% [markdown]
# ## Model Building

# %% [markdown]
# Applying an algorithm for suffix stripping

# %%
ps = PorterStemmer()

# %%
def stem(text):
  lst = []
  for word in text.split():
    lst.append(ps.stem(word))

  return ' '.join(lst)

# %%
new_df['summary'][0]
# Out:
# 'restaking 3.2m ethereum mainnet renzo is a liquid restaking token (lrt) and strategy manager for eigenlayer. it is the interface to the eigenlayer ecosystem securing actively validated services (avss) and offering a higher yield than eth staking. stake eth to obtain ezeth and earn eigenlayer and renzo points'

# %%
stem(new_df['summary'][0])
# Out:
# 'restak 3.2m ethereum mainnet renzo is a liquid restak token (lrt) and strategi manag for eigenlayer. it is the interfac to the eigenlay ecosystem secur activ valid servic (avss) and offer a higher yield than eth staking. stake eth to obtain ezeth and earn eigenlay and renzo point'

# %%
new_df['summary'] = new_df['summary'].apply(stem)

# %% [markdown]
# Formating datasets to vectors rows are samples and columns are common words

# %%
cv = CountVectorizer(max_features=1000, stop_words='english')
vectors = cv.fit_transform(new_df['summary']).toarray()
vectors.shape
# Out:
# (138, 1000)

# %%
cv.get_feature_names_out()[:100]
# Out:
# array(['0m', '10', '1014306106', '10m', '11', '119m', '13m', '16', '173',
#        '17m', '18', '18m', '19', '1m', '2024', '20m', '21', '215m',
#        '225m', '22m', '23', '25m', '273m', '29m', '2m', '3000', '30m',
#        '33m', '3m', '458m', '4m', '5000', '5m', '64', '6m', '726', '726m',
#        '72m', '7m', '80m', '8m', '95', '9m', 'abstract', 'access',
#        'accomplish', 'account', 'achiev', 'activ', 'add', 'addit',
#        'address', 'adopt', 'advanc', 'advantag', 'aggreg', 'ai',
#        'airdrop', 'algorithm', 'allbridg', 'allow', 'alpha', 'alphadrop',
#        'ambassador', 'ambient', 'amitej', 'amm', 'analysi', 'analyt',
#        'ancient8', 'android', 'ani', 'announc', 'anoth', 'app', 'applic',
#        'application', 'applications', 'apps', 'apr', 'apto', 'arbitrari',
#        'arbitrum', 'architectur', 'argent', 'arraki', 'articl', 'asset',
#        'assets', 'assets2', 'atlendi', 'attempt', 'attention', 'auction',
#        'aurora', 'autom', 'autonom', 'avail', 'avalanch', 'averag'],
#       dtype=object)

# %% [markdown]
# Getting similarity of each project to others

# %%
similarity = cosine_similarity(vectors)
similarity.shape
# Out:
# (138, 138)

# %% [markdown]
# Evaluating model

# %%
SIMILAR_PROJECT_COUNT = 10

# %%
sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x: x[1])[1:SIMILAR_PROJECT_COUNT+1]
# Out:
# [(32, 0.5146502354656655),
#  (30, 0.3674234614174767),
#  (8, 0.3423265984407289),
#  (14, 0.27386127875258304),
#  (19, 0.22206996305928162),
#  (122, 0.21081851067789195),
#  (46, 0.1863389981249825),
#  (23, 0.18195633571851272),
#  (1, 0.17712297710801905),
#  (104, 0.16903085094570333)]

# %%
for i in range(similarity.shape[0]):
  project_title = df['title'][i]
  similar_projects_ids = [id_prob[0] for id_prob in sorted(list(enumerate(similarity[i])), reverse=True, key=lambda x: x[1])[1:SIMILAR_PROJECT_COUNT+1]]
  try:
    similar_projects = [df.query('id == @id + 1')['title'].iloc[0] for id in similar_projects_ids]

    print(project_title, similar_projects)
  except Exception as ex:
    print(ex, similar_projects_ids)
# Out:
# Renzo ['Eigen Layer', 'Ether.fi', 'Kelp DAO', 'Swell', 'Helio Protocol', 'Charm', 'Rage Trade', 'zkSync', 'Butter', 'Volmex Finance']
# Butter ['Hyperliquid', 'Charm', 'Ekubo', 'Volmex Finance', 'ChainHop', 'Metamask', 'Tevaera', 'StarkDefi', 'Primex Finance', 'DefiLlama']
# Parcl ['Hyperliquid', 'KiloEx', 'Synquote', 'Drift Protocol', 'Derivio', 'Ekubo', 'Arrakis Finance', 'Scroll', 'Rage Trade', 'Ambient']
# Derivio ['KiloEx', 'Synquote', 'Drift Protocol', 'Parcl', 'Rage Trade', 'Vest Exchange', 'Scroll', 'Polynomial', 'Hyperliquid', 'ZKX Protocol']
# Ambient ['Ekubo', 'Swaap', 'Charm', 'Maverick', 'Volmex Finance', 'Primitive Finance', 'Primex Finance', 'Arrakis Finance', 'Bebop', 'Shell Protocol']
# BracketX ['Shell Protocol', 'Rage Trade', 'DeFi Saver', 'Synquote', 'KiloEx', 'Voltz Protocol', 'Diamond Protocol', 'Dolomite', 'Odos', 'Vest Exchange']
# Nostra Finance ['Sentiment', 'Timeswap', 'Dolomite', 'Drift Protocol', 'Marginfi', 'Volmex Finance', 'Helio Protocol', 'Davos Protocol', 'Ekubo', 'Atlendis']
# Rainbow ['Taho', 'Argent', 'Slingshot', 'Zerion', 'Bungee', 'Metamask', 'Phantom', 'Zapper', 'Mint.fun', 'Martian Wallet']
# Kelp DAO ['Eigen Layer', 'Ether.fi', 'Swell', 'Renzo', 'Helio Protocol', 'Raft', 'Arrakis Finance', 'Ekubo', 'Charm', 'Hyperliquid']
# Hyperlane ['Wormhole', 'DeBridge', 'Li.Fi', 'Bungee', 'Allbridge Core', 'ioTube', 'Metamask', 'ChainHop', 'Base', 'Octus Bridge']
# Ekubo ['Swaap', 'Volmex Finance', 'Arrakis Finance', 'Ambient', 'StarkDefi', 'Nostra Finance', 'Primitive Finance', 'Maverick', 'Shell Protocol', 'Charm']
# Frame ['Zora', 'Ten (formerly Obscuro)', 'Briq', 'Base', 'Taiko', 'Aztec / zk.money', 'Mode', 'StarkNet', 'Mint.fun', 'mySwap']
# Hyperliquid ['Parcl', 'Synquote', 'Aboard Exchange', 'Rage Trade', 'Butter', 'Drift Protocol', 'Charm', 'Ambient', 'Dolomite', 'Ekubo']
# dappOS ['Volmex Finance', 'Hinkal Protocol', 'Ekubo', 'Polyhedra', 'StarkNet', 'Arrakis Finance', 'Via Protocol', 'Optimism', 'Bungee', 'Swaap']
# Swell ['Ether.fi', 'Kelp DAO', 'Helio Protocol', 'Eigen Layer', 'Raft', 'Volmex Finance', 'Renzo', 'Charm', 'Arrakis Finance', 'DeFi Saver']
# Kinza ['Marginfi', 'Sentiment', 'Atlendis', 'Dolomite', 'Timeswap', 'Davos Protocol', 'Volmex Finance', 'Drift Protocol', 'Nostra Finance', 'DeFi Saver']
# Scroll ['Base', 'Linea', 'Aztec / zk.money', 'DeFi Saver', 'Primitive Finance', 'Allbridge Core', 'Metamask', 'DeBridge', 'Briq', 'Zora']
# Ten (formerly Obscuro) ['Aztec / zk.money', 'Frame', 'zkLink', 'Omni Network', 'Taiko', 'Polyhedra', 'Scroll', 'zkLend', 'Specular', 'Shardeum']
# Drift Protocol ['Marginfi', 'Derivio', 'Nostra Finance', 'Dolomite', 'Atlendis', 'Sentiment', 'Parcl', 'Voltz Protocol', 'Timeswap', 'Kinza']
# Helio Protocol ['Raft', 'Swell', 'Nostra Finance', 'Ether.fi', 'Kelp DAO', 'Davos Protocol', 'Hinkal Protocol', 'Eigen Layer', 'Primitive Finance', 'Drift Protocol']
# Ancient8 ['zkLend', 'Opside', 'Omni Network', 'Base', 'Specular', 'Frame', 'Ten (formerly Obscuro)', 'Mode', 'zkLink', 'Optimism']
# KiloEx ['Derivio', 'Parcl', 'Synquote', 'Scroll', 'Arrakis Finance', 'Swaap', 'Rage Trade', 'BracketX', 'Nostra Finance', 'Linea']
# Mode ['Aztec / zk.money', 'Omni Network', 'Base', 'Frame', 'Ten (formerly Obscuro)', 'Scroll', 'Optimism', 'StarkNet', 'Opside', 'Primitive Finance']
# zkSync ['zkLink', 'Optimism', 'Tevaera', 'Orbiter', 'Raise Finance', 'SyncSwap', 'StarkNet', 'Bungee', 'zkLend', 'Aztec / zk.money']
# Wormhole ['Allbridge Core', 'Li.Fi', 'ChainHop', 'Bungee', 'ioTube', 'Octus Bridge', 'Mayan Finance', 'DeBridge', 'Hyperlane', 'Magpie']
# Nocturne ['Hinkal Protocol', 'Opyn', 'DeFi Saver', 'Symmetry Finance', 'Ether.fi', 'Eigen Layer', 'Voltz Protocol', 'Aztec / zk.money', 'Charm', 'zkSync']
# Hinkal Protocol ['Nocturne', 'Volmex Finance', 'Arrakis Finance', 'dappOS', 'Bungee', 'Charm', 'DeBridge', 'Via Protocol', 'Helio Protocol', 'Slingshot']
# Marginfi ['Sentiment', 'Drift Protocol', 'Timeswap', 'Kinza', 'Nostra Finance', 'Atlendis', 'Volmex Finance', 'Symmetry Finance', 'Davos Protocol', 'Dolomite']
# Base ['Scroll', 'Allbridge Core', 'Bungee', 'Aztec / zk.money', 'Primitive Finance', 'Linea', 'DeFi Saver', 'Zapper', 'Frame', 'Metamask']
# Orderly Network ['Symmetry Finance', 'Primex Finance', 'Ambient', 'Matcha', 'Mayan Finance', 'SyncSwap', 'ZKEX', 'Shell Protocol', 'Bebop', 'Vest Exchange']
# Ether.fi ['Eigen Layer', 'Kelp DAO', 'Swell', 'Zora', 'Renzo', 'Raft', 'Mint.fun', 'Helio Protocol', 'Volmex Finance', 'Mint Chain']
# RedStone ['Swaap', 'Primitive Finance', 'Atlendis', 'dappOS', 'Volmex Finance', 'DeFi Saver', 'Shell Protocol', 'Opyn', 'PerpDEX', 'Ekubo']
# Eigen Layer ['Renzo', 'Kelp DAO', 'Ether.fi', 'Swell', 'Primitive Finance', 'Helio Protocol', 'Volmex Finance', 'Primex Finance', 'Nocturne', 'Voltz Protocol']
# Linea ['Scroll', 'Zora', 'Base', 'DeBridge', 'Tabi', 'Primitive Finance', 'Rage Trade', 'Metamask', 'Via Protocol', 'KiloEx']
# Prime Protocol ['Via Protocol', 'Jumper Exchange', 'ChainHop', 'Matcha', 'Mayan Finance', 'Magpie', 'Davos Protocol', 'Li.Fi', 'DeBridge', 'Allbridge Core']
# Layer Zero ['Atlendis', 'Mayan Finance', 'Prime Protocol', 'DeBridge', 'Wormhole', 'Magpie', 'Kinza', 'Via Protocol', 'Rage Trade', 'ZetaChain']
# Polyhedra ['Li.Fi', 'Via Protocol', 'zkLink', 'DeBridge', 'DeFi Saver', 'Aztec / zk.money', 'Ten (formerly Obscuro)', 'Taho', 'Scroll', 'Bungee']
# Maverick ['Primitive Finance', 'Charm', 'Swaap', 'Ambient', 'Arrakis Finance', 'Volmex Finance', 'Ekubo', 'DeFi Saver', 'Raft', 'Polymarket']
# StarkNet ['zkLend', 'mySwap', 'Jedi Swap', 'ZKX Protocol', 'Taiko', 'StarkDefi', 'Optimism', 'Base', 'zkSync', 'Aztec / zk.money']
# Taiko ['Omni Network', 'StarkNet', 'Frame', 'Ten (formerly Obscuro)', 'Specular', 'ZetaChain', 'Scroll', 'Tevaera', 'Raise Finance', 'Primex Finance']
# Satori ['Aboard Exchange', 'Orbiter', 'Hyperliquid', 'Derivio', 'Scroll', 'Tevaera', 'Raise Finance', 'Prime Protocol', 'Hinkal Protocol', 'Via Protocol']
# Zora ['Mint.fun', 'Mint Chain', 'Briq', 'Ether.fi', 'Frame', 'Linea', 'dotbit (.bit)', 'Scroll', 'Tabi', 'Base']
# Fuel Network ['Briq', 'Omni Network', 'Opside', 'Primex Finance', 'Scroll', 'Shardeum', 'zkLend', 'Ten (formerly Obscuro)', 'mySwap', 'Raise Finance']
# ZKEX ['Brine', 'zkSync', 'Raise Finance', 'zkLink', 'Matcha', 'Orderly Network', 'SyncSwap', 'Tevaera', 'StarkDefi', 'Satori']
# Brine ['ZKEX', 'Primex Finance', 'ZKX Protocol', 'StarkDefi', 'Bebop', 'Matcha', 'Ambient', 'Magpie', 'Orderly Network', 'Prime Protocol']
# zkLink ['zkSync', 'Opside', 'Polyhedra', 'Omni Network', 'Optimism', 'Ten (formerly Obscuro)', 'Aztec / zk.money', 'Base', 'zkLend', 'Scroll']
# Rage Trade ['Vest Exchange', 'Diamond Protocol', 'Beamer', 'Synquote', 'Vovo Finance', 'Hyperliquid', 'Taho', 'Via Protocol', 'BracketX', 'Arrakis Finance']
# Raft ['Helio Protocol', 'Ether.fi', 'Swell', 'Kelp DAO', 'Nostra Finance', 'Maverick', 'Davos Protocol', 'Hinkal Protocol', 'Arrakis Finance', 'Charm']
# Dolomite ['Timeswap', 'Davos Protocol', 'Nostra Finance', 'Sentiment', 'Drift Protocol', 'Kinza', 'DeFi Saver', 'Synquote', 'Vest Exchange', 'Volmex Finance']
# Opside ['Omni Network', 'Briq', 'zkLink', 'ZetaChain', 'Shardeum', 'Raise Finance', 'Primex Finance', 'Jedi Swap', 'Polyhedra', 'Specular']
# DeBridge ['Li.Fi', 'Bungee', 'Allbridge Core', 'Mayan Finance', 'ioTube', 'Via Protocol', 'ChainHop', 'Orbiter', 'Jumper Exchange', 'Wormhole']
# DeBank ['Metamask', 'Wormhole', 'CoinStats', 'DefiLlama', 'Martian Wallet', 'SetProtcol', 'Allbridge Core', 'Superfluid', 'Magpie', 'Zapper']
# Mint.fun ['Zora', 'Mint Chain', 'Ether.fi', 'Briq', 'Rainbow', 'dotbit (.bit)', 'Frame', 'Base', 'ParaSpace', 'Unstoppable Domains']
# Metamask ['Phantom', 'Rainbow', 'Taho', 'Martian Wallet', 'Allbridge Core', 'Scroll', 'Bungee', 'Argent', 'Jumper Exchange', 'Base']
# rysk finance ['DeFi Saver', 'Vovo Finance', 'Briq', 'Vest Exchange', 'Fuel Network', 'Side Protocol', 'Rage Trade', 'StarkDefi', 'Primitive Finance', 'mySwap']
# Matcha ['Slingshot', 'Mayan Finance', 'ChainHop', 'Bungee', 'Zapper', 'Via Protocol', 'Jumper Exchange', 'Li.Fi', 'DefiLlama', 'Allbridge Core']
# Optimism ['zkSync', 'zkLink', 'Scroll', 'DeFi Saver', 'Metamask', 'StarkNet', 'Bungee', 'Aztec / zk.money', 'Orbiter', 'Base']
# LayerSwap ['Orbiter', 'Bungee', 'Layer3', 'Via Protocol', 'Slingshot', 'DeBridge', 'Rage Trade', 'Volmex Finance', 'Jumper Exchange', 'Taho']
# Layer3 ['Bungee', 'Jumper Exchange', 'Via Protocol', 'Zerion', 'Orbiter', 'Slingshot', 'Zapper', 'Li.Fi', 'DefiLlama', 'Arrakis Finance']
# RabbitHole ['Layer3', 'CoinStats', 'Superfluid', 'Base', 'Sablier', 'Primitive Finance', 'Mirror', 'DeBank', 'DeBridge', 'DeFi Saver']
# Li.Fi ['Jumper Exchange', 'Bungee', 'Via Protocol', 'ChainHop', 'Wormhole', 'DeBridge', 'Orbiter', 'Zapper', 'Allbridge Core', 'DefiLlama']
# Jumper Exchange ['Li.Fi', 'Via Protocol', 'Bungee', 'DefiLlama', 'ChainHop', 'Mayan Finance', 'Layer3', 'Slingshot', 'Allbridge Core', 'DeBridge']
# Bungee ['ChainHop', 'Li.Fi', 'Jumper Exchange', 'Via Protocol', 'Zapper', 'Zerion', 'Layer3', 'Slingshot', 'Allbridge Core', 'Orbiter']
# Bebop ['Slingshot', 'Taho', 'Vest Exchange', 'Charm', 'DeFi Saver', 'Mean Finance', 'Layer3', 'Diamond Protocol', 'DefiLlama', 'Shell Protocol']
# Zerion ['Zapper', 'Bungee', 'DefiLlama', 'Slingshot', 'Rainbow', 'Layer3', 'Li.Fi', 'Orbiter', 'ChainHop', 'Jumper Exchange']
# Synquote ['Hyperliquid', 'Derivio', 'Opyn', 'Rage Trade', 'Parcl', 'Dolomite', 'KiloEx', 'Scroll', 'Diamond Protocol', 'Slingshot']
# Tabi ['Zora', 'Briq', 'Linea', 'Polyhedra', 'Mint.fun', 'Slingshot', 'Wormhole', 'Zapper', 'Mirror', 'Rainbow']
# Omni Network ['Opside', 'zkLink', 'ZetaChain', 'Taiko', 'Ten (formerly Obscuro)', 'Side Protocol', 'Scroll', 'Mode', 'Base', 'Briq']
# Diamond Protocol ['Arrakis Finance', 'Slingshot', 'Rage Trade', 'SyncSwap', 'Bebop', 'Scroll', 'Synquote', 'Swaap', 'Volmex Finance', 'Taho']
# Davos Protocol ['Timeswap', 'Dolomite', 'Sentiment', 'Nostra Finance', 'Prime Protocol', 'Kinza', 'Helio Protocol', 'Marginfi', 'Atlendis', 'Raft']
# zkPass ['zCloak', 'zkLend', 'Polyhedra', 'zkLink', 'Shardeum', 'ZKEX', 'Rage Trade', 'Ten (formerly Obscuro)', 'Layer3', 'SyncSwap']
# Martian Wallet ['Taho', 'Phantom', 'Metamask', 'Pontem Network', 'Argent', 'Rainbow', 'DeBank', 'CoinStats', 'Scroll', 'ZetaChain']
# Swaap ['Primitive Finance', 'Volmex Finance', 'Arrakis Finance', 'Maverick', 'Ekubo', 'Charm', 'Ambient', 'PerpDEX', 'KiloEx', 'Diamond Protocol']
# Sentiment ['Timeswap', 'Marginfi', 'Nostra Finance', 'Dolomite', 'Kinza', 'Davos Protocol', 'Atlendis', 'Volmex Finance', 'ParaSpace', 'Drift Protocol']
# Slingshot ['Matcha', 'Zapper', 'Bungee', 'Rainbow', 'Taho', 'ChainHop', 'Zerion', 'Li.Fi', 'Via Protocol', 'Orbiter']
# DeFi Saver ['Primitive Finance', 'Via Protocol', 'Aztec / zk.money', 'Cozy Finance', 'Charm', 'DefiLlama', 'Volmex Finance', 'Vovo Finance', 'Scroll', 'SetProtcol']
# ZetaChain ['Opside', 'Omni Network', 'Briq', 'Shardeum', 'zkLink', 'Metamask', 'StarkDefi', 'Raise Finance', 'Primex Finance', 'Scroll']
# Aboard Exchange ['Hyperliquid', 'Satori', 'Rage Trade', 'ZKX Protocol', 'Opyn', 'Synquote', 'Polynomial', 'ChainHop', 'Bungee', 'Via Protocol']
# Polynomial ['ZKX Protocol', 'Derivio', 'Diamond Protocol', 'Rage Trade', 'BracketX', 'Scroll', 'Linea', 'Voltz Protocol', 'Hinkal Protocol', 'Aboard Exchange']
# Mint Chain ['Zora', 'Mint.fun', 'Ether.fi', 'Unstoppable Domains', 'Briq', 'dotbit (.bit)', 'Omni Network', 'ParaSpace', 'Frame', 'Tabi']
# Squid ['ChainHop', 'Bungee', 'DeBridge', 'Jumper Exchange', 'Slingshot', 'Zapper', 'Li.Fi', 'Via Protocol', 'Zerion', 'DefiLlama']
# Cask Protocol ['Jumper Exchange', 'Taho', 'Layer3', 'Via Protocol', 'Bungee', 'Vovo Finance', 'zkLend', 'Li.Fi', 'DefiLlama', 'Slingshot']
# Mean Finance ['DeFi Saver', 'Vest Exchange', 'Bebop', 'Slingshot', 'Arrakis Finance', 'Via Protocol', 'Matcha', 'ChainHop', 'SetProtcol', 'Odos']
# PerpDEX ['SyncSwap', 'Primitive Finance', 'DeFi Saver', 'Scroll', 'Swaap', 'Magpie', 'Metamask', 'Primex Finance', 'Shell Protocol', 'StarkDefi']
# Arrakis Finance ['Volmex Finance', 'Diamond Protocol', 'Swaap', 'Ekubo', 'Primitive Finance', 'DeFi Saver', 'Layer3', 'Charm', 'Hinkal Protocol', 'Slingshot']
# Via Protocol ['Jumper Exchange', 'Li.Fi', 'Bungee', 'DeFi Saver', 'Mayan Finance', 'Allbridge Core', 'ChainHop', 'DeBridge', 'Layer3', 'DefiLlama']
# SyncSwap ['StarkDefi', 'zkSync', 'PerpDEX', 'Diamond Protocol', 'Raise Finance', 'Tevaera', 'Primitive Finance', 'mySwap', 'Primex Finance', 'DeFi Saver']
# Allbridge Core ['Mayan Finance', 'ChainHop', 'Bungee', 'Wormhole', 'Via Protocol', 'Octus Bridge', 'ioTube', 'Li.Fi', 'DeBridge', 'Base']
# Zapper ['Zerion', 'Bungee', 'Slingshot', 'ChainHop', 'Li.Fi', 'DefiLlama', 'Mayan Finance', 'Orbiter', 'Matcha', 'Allbridge Core']
# Argent ['Rainbow', 'Taho', 'Phantom', 'Martian Wallet', 'Metamask', 'Aztec / zk.money', 'Bebop', 'Slingshot', 'Charm', 'Pontem Network']
# SetProtcol ['Cozy Finance', 'DeFi Saver', 'Polymarket', 'Volmex Finance', 'DefiLlama', 'Zapper', 'Opyn', 'Charm', 'Arrakis Finance', 'Bebop']
# zkLend ['StarkNet', 'Briq', 'mySwap', 'Shardeum', 'Primitive Finance', 'StarkDefi', 'Jedi Swap', 'Via Protocol', 'ZKX Protocol', 'Beamer']
# Symmetry Finance ['Mayan Finance', 'Orderly Network', 'Zerion', 'Volmex Finance', 'Voltz Protocol', 'Marginfi', 'DeFi Saver', 'Zapper', 'Phantom', 'Charm']
# Magpie ['ChainHop', 'Wormhole', 'Allbridge Core', 'Mayan Finance', 'Prime Protocol', 'Matcha', 'Metamask', 'Bungee', 'Li.Fi', 'PerpDEX']
# Superfluid ['Sablier', 'DeFi Saver', 'Primitive Finance', 'Aztec / zk.money', 'Vovo Finance', 'Scroll', 'Base', 'Via Protocol', 'SetProtcol', 'Allbridge Core']
# Voltz Protocol ['Primitive Finance', 'Charm', 'Drift Protocol', 'Atlendis', 'Volmex Finance', 'DeFi Saver', 'Symmetry Finance', 'Opyn', 'BracketX', 'Dolomite']
# Aztec / zk.money ['DeFi Saver', 'Scroll', 'Primitive Finance', 'Ten (formerly Obscuro)', 'Base', 'zkLink', 'Polyhedra', 'Allbridge Core', 'Mode', 'Tevaera']
# Primitive Finance ['DeFi Saver', 'Swaap', 'Charm', 'Maverick', 'Volmex Finance', 'Voltz Protocol', 'Aztec / zk.money', 'Scroll', 'Primex Finance', 'Via Protocol']
# ZKX Protocol ['StarkDefi', 'StarkNet', 'mySwap', 'zkLend', 'Jedi Swap', 'Briq', 'Polynomial', 'Brine', 'Derivio', 'Aboard Exchange']
# Cozy Finance ['DeFi Saver', 'SetProtcol', 'Vovo Finance', 'Opyn', 'Volmex Finance', 'Charm', 'DefiLlama', 'Shell Protocol', 'Primitive Finance', 'Polymarket']
# ChainHop ['Bungee', 'Mayan Finance', 'Allbridge Core', 'Squid', 'Matcha', 'Li.Fi', 'Zapper', 'Slingshot', 'Jumper Exchange', 'Wormhole']
# Beamer ['Orbiter', 'Rage Trade', 'zkLend', 'Li.Fi', 'Allbridge Core', 'Metamask', 'Bungee', 'Wormhole', 'Octus Bridge', 'DeBridge']
# Vovo Finance ['DeFi Saver', 'Cozy Finance', 'Rage Trade', 'Superfluid', 'rysk finance', 'Volmex Finance', 'Shell Protocol', 'Opyn', 'Cask Protocol', 'BracketX']
# Phantom ['Metamask', 'Argent', 'Martian Wallet', 'Taho', 'Rainbow', 'Allbridge Core', 'Symmetry Finance', 'Mayan Finance', 'CoinStats', 'Scroll']
# Volmex Finance ['Arrakis Finance', 'Primitive Finance', 'Atlendis', 'DeFi Saver', 'Swaap', 'ChainHop', 'Ekubo', 'Charm', 'Bungee', 'Nostra Finance']
# Snapshot ['Layer3', 'zkPass', 'Shell Protocol', 'Beamer', 'Arrakis Finance', 'Rage Trade', 'zkLend', 'Bebop', 'Prime Protocol', 'DefiLlama']
# StarkDefi ['Jedi Swap', 'ZKX Protocol', 'mySwap', 'SyncSwap', 'Primex Finance', 'Briq', 'zkLend', 'Ekubo', 'Side Protocol', 'StarkNet']
# Specular ['Shardeum', 'Ten (formerly Obscuro)', 'Briq', 'StarkDefi', 'Opside', 'Raise Finance', 'Primex Finance', 'zkLend', 'Taiko', 'Ancient8']
# Taho ['Rainbow', 'Argent', 'Slingshot', 'Martian Wallet', 'Phantom', 'Metamask', 'Via Protocol', 'Bebop', 'DeFi Saver', 'Polyhedra']
# CoinStats ['DeBank', 'RabbitHole', 'Metamask', 'Martian Wallet', 'Phantom', 'DeBridge', 'Zerion', 'Superfluid', 'Taho', 'Argent']
# zCloak ['zkPass', 'Polyhedra', 'StarkNet', 'zkLink', 'ZetaChain', 'Omni Network', 'Aztec / zk.money', 'DeBridge', 'Mode', 'Base']
# ioTube ['ChainHop', 'Allbridge Core', 'DeBridge', 'Wormhole', 'Bungee', 'Octus Bridge', 'Li.Fi', 'Mayan Finance', 'Orbiter', 'Zapper']
# ParaSpace ['Sentiment', 'Timeswap', 'Zora', 'Briq', 'Atlendis', 'Mint.fun', 'Marginfi', 'Diamond Protocol', 'Dolomite', 'Volmex Finance']
# Vest Exchange ['Rage Trade', 'Bebop', 'Mean Finance', 'Side Protocol', 'Shell Protocol', 'Dolomite', 'Derivio', 'Odos', 'BracketX', 'Ambient']
# Pontem Network ['Martian Wallet', 'zkLink', 'Metamask', 'Aztec / zk.money', 'Base', 'Phantom', 'Optimism', 'Scroll', 'Opside', 'Rainbow']
# Mayan Finance ['Allbridge Core', 'ChainHop', 'Matcha', 'Bungee', 'Via Protocol', 'Jumper Exchange', 'Zapper', 'DeBridge', 'Li.Fi', 'Octus Bridge']
# dotbit (.bit) ['Unstoppable Domains', 'Zora', 'Mint.fun', 'Rainbow', 'Ether.fi', 'Taho', 'Mirror', 'Mint Chain', 'Tabi', 'Via Protocol']
# mySwap ['Jedi Swap', 'StarkDefi', 'StarkNet', 'Briq', 'zkLend', 'Side Protocol', 'ZKX Protocol', 'Primex Finance', 'Volmex Finance', 'DeFi Saver']
# Timeswap ['Sentiment', 'Dolomite', 'Davos Protocol', 'Nostra Finance', 'Marginfi', 'Kinza', 'ParaSpace', 'Atlendis', 'Drift Protocol', 'Volmex Finance']
# Orbiter ['Bungee', 'LayerSwap', 'Li.Fi', 'Zapper', 'DeBridge', 'zkSync', 'Layer3', 'Slingshot', 'Allbridge Core', 'Zerion']
# Unstoppable Domains ['dotbit (.bit)', 'Bebop', 'Rainbow', 'Zora', 'Volmex Finance', 'Mint.fun', 'Mint Chain', 'Odos', 'Ether.fi', 'Linea']
# Raise Finance ['Tevaera', 'zkSync', 'Briq', 'Opside', 'Primex Finance', 'SyncSwap', 'Shardeum', 'StarkDefi', 'Omni Network', 'Specular']
# Charm ['Primitive Finance', 'DeFi Saver', 'Maverick', 'Swaap', 'Volmex Finance', 'Voltz Protocol', 'Ambient', 'Arrakis Finance', 'Bebop', 'Polymarket']
# Shardeum ['Briq', 'zkLend', 'Opside', 'ZetaChain', 'Specular', 'Raise Finance', 'Primex Finance', 'Ten (formerly Obscuro)', 'Metamask', 'Jedi Swap']
# Shell Protocol ['DeFi Saver', 'BracketX', 'Ekubo', 'Zapper', 'Bebop', 'Polymarket', 'Volmex Finance', 'Vest Exchange', 'Ambient', 'Arrakis Finance']
# Mirror ['dotbit (.bit)', 'Tabi', 'Polyhedra', 'Rainbow', 'SetProtcol', 'Aztec / zk.money', 'Superfluid', 'Taho', 'Volmex Finance', 'Ether.fi']
# Sablier ['Superfluid', 'Vovo Finance', 'SetProtcol', 'ChainHop', 'DeBank', 'Cask Protocol', 'Volmex Finance', 'Sentiment', 'RabbitHole', 'DeFi Saver']
# Jedi Swap ['mySwap', 'StarkDefi', 'Briq', 'StarkNet', 'Primex Finance', 'zkLend', 'ZKX Protocol', 'Opside', 'Metamask', 'DeFi Saver']
# Polymarket ['DeFi Saver', 'SetProtcol', 'Charm', 'Shell Protocol', 'Opyn', 'Maverick', 'Volmex Finance', 'Cozy Finance', 'Symmetry Finance', 'Zerion']
# Octus Bridge ['Allbridge Core', 'Wormhole', 'ioTube', 'Mayan Finance', 'Bungee', 'Orbiter', 'Li.Fi', 'Zapper', 'DeBridge', 'ChainHop']
# Atlendis ['Volmex Finance', 'Kinza', 'Marginfi', 'Sentiment', 'Opyn', 'Primitive Finance', 'Drift Protocol', 'Timeswap', 'Nostra Finance', 'Voltz Protocol']
# Tevaera ['zkSync', 'Raise Finance', 'Aztec / zk.money', 'Orbiter', 'SyncSwap', 'DeFi Saver', 'Charm', 'Taiko', 'zkLink', 'StarkNet']
# Briq ['Jedi Swap', 'Zora', 'zkLend', 'Opside', 'mySwap', 'Primex Finance', 'Shardeum', 'StarkDefi', 'Frame', 'Fuel Network']
# Odos ['Volmex Finance', 'Slingshot', 'Taho', 'Matcha', 'Zapper', 'Bebop', 'DefiLlama', 'Vest Exchange', 'Bungee', 'ChainHop']
# Opyn ['DeFi Saver', 'Synquote', 'Atlendis', 'Cozy Finance', 'SetProtcol', 'Primitive Finance', 'Polymarket', 'Volmex Finance', 'Charm', 'Symmetry Finance']
# DefiLlama ['Jumper Exchange', 'Zerion', 'DeFi Saver', 'Bungee', 'Zapper', 'Li.Fi', 'Via Protocol', 'Layer3', 'Matcha', 'Slingshot']
# Primex Finance ['Briq', 'StarkDefi', 'Primitive Finance', 'DeFi Saver', 'Jedi Swap', 'Opside', 'mySwap', 'Raise Finance', 'Ambient', 'Charm']
# Side Protocol ['mySwap', 'StarkDefi', 'Omni Network', 'Vest Exchange', 'Jedi Swap', 'SyncSwap', 'Base', 'Metamask', 'Linea', 'Opside']

# %%
similarity_df = pd.DataFrame(columns=['id', 'similar_projects_ids'])

for i in range(similarity.shape[0]):
    id_value = df['id'][i]
    similar_projects_ids = ', '.join([str(id_prob[0]) for id_prob in sorted(enumerate(similarity[i]), reverse=True, key=lambda x: x[1])[1:SIMILAR_PROJECT_COUNT+1]])

    similarity_df = similarity_df.append({'id': id_value, 'similar_projects_ids': similar_projects_ids}, ignore_index=True)

# %%
similarity_df.head()
# Out:
#   id                           similar_projects_ids
# 0  1         32, 30, 8, 14, 19, 122, 46, 23, 1, 104
# 1  2  12, 122, 10, 104, 100, 53, 131, 106, 136, 135
# 2  3           12, 21, 65, 18, 3, 10, 84, 16, 46, 4
# 3  4         21, 65, 18, 2, 46, 113, 16, 78, 12, 98
# 4  5     10, 72, 122, 37, 104, 97, 136, 84, 63, 124

# %%
similarity_df.to_csv('similarity.csv', index=False)
